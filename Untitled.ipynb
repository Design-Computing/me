# %%
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import os

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (20, 10)

# %%
saved_style_state = matplotlib.rcParams.copy() #give us a style state to go back to

# %%
if os.path.isfile("Test Batting.csv"):
    filepath = "Test Batting.csv"
    print("loading from file")
TestBatting = pd.read_csv(filepath)
print("done")
# Out:
# loading from file
# done

# %%
TestBatting.sort_values(by = 'Ducks Scored').head(2)
# Out:
#                         Player Career Span  Career Start  Career End  \
# 2948  Khaled Ahmed (2018-2018)   2018-2018          2018        2018
# 1794     LR Pierre (1948-1948)   1948-1948          1948        1948
#
#       Matches Played Innings Batted Not Outs Runs Scored  \
# 2948               1              -        -           -
# 1794               1              -        -           -
#
#      Highest Innings Score Highest Innings Score Num Batting Avg  \
# 2948                     -                         -           -
# 1794                     -                         -           -
#
#      Hundreds Scored Scores Of Fifty Or More Ducks Scored      Country  \
# 2948               -                       -            -   Bangladesh
# 1794               -                       -            -  West Indies
#
#       Player Count  10000+ Runs Scored  50+ Batting Avg
# 2948             1                   0                0
# 1794             1                   0                0

# %%
The Ashes
"First started in 1882"
Aussies have won 33
England have won 32
Drawn 5
Cricket series held every 2 years between Australia and England
One of the most iconic cricket series played

# %%
Show u will win this series based off players statistics

# %%
EnglandPeople = TestBatting[TestBatting['Country'] == 'England']
EnglandPeople.head(2)
# Out:
#                  Player Career Span  Career Start  Career End  Matches Played  \
# 0   AN Cook (2006-2018)   2006-2018          2006        2018             161
# 1  GA Gooch (1975-1995)   1975-1995          1975        1995             118
#
#   Innings Batted Not Outs Runs Scored Highest Innings Score  \
# 0            291       16       12472                   294
# 1            215        6        8900                   333
#
#   Highest Innings Score Num Batting Avg Hundreds Scored  \
# 0                       294       45.35              33
# 1                       333       42.58              20
#
#   Scores Of Fifty Or More Ducks Scored  Country  Player Count  \
# 0                      57            9  England             1
# 1                      46           13  England             1
#
#    10000+ Runs Scored  50+ Batting Avg
# 0                   1                0
# 1                   0                0

# %%
EnglandPeople.sort_values(by = 'Batting Avg', ascending = True).head(2)
# Out:
#                   Player Career Span  Career Start  Career End  \
# 688  CF Root (1926-1926)   1926-1926          1926        1926
# 687  HD Read (1935-1935)   1935-1935          1935        1935
#
#      Matches Played Innings Batted Not Outs Runs Scored Highest Innings Score  \
# 688               3              -        -           -                     -
# 687               1              -        -           -                     -
#
#     Highest Innings Score Num Batting Avg Hundreds Scored  \
# 688                         -           -               -
# 687                         -           -               -
#
#     Scores Of Fifty Or More Ducks Scored  Country  Player Count  \
# 688                       -            -  England             1
# 687                       -            -  England             1
#
#      10000+ Runs Scored  50+ Batting Avg
# 688                   0                0
# 687                   0                0

# %%
EnglandPeople['Career Start'].value_counts().plot(kind='bar')

# %%
EnglandPeople = TestBatting[TestBatting['Career Start'] > 2000]
EnglandPeople.head(2)
# Out:
#                      Player Career Span  Career Start  Career End  \
# 0       AN Cook (2006-2018)   2006-2018          2006        2018
# 4  KP Pietersen (2005-2014)   2005-2014          2005        2014
#
#    Matches Played Innings Batted Not Outs Runs Scored Highest Innings Score  \
# 0             161            291       16       12472                   294
# 4             104            181        8        8181                   227
#
#   Highest Innings Score Num Batting Avg Hundreds Scored  \
# 0                       294       45.35              33
# 4                       227       47.28              23
#
#   Scores Of Fifty Or More Ducks Scored  Country  Player Count  \
# 0                      57            9  England             1
# 4                      35           10  England             1
#
#    10000+ Runs Scored  50+ Batting Avg
# 0                   1                0
# 4                   0                0

# %%
EnglandPeople.loc[EnglandPeople['Player'] == 'JE Root (2012-2018)']
# Out:
#                  Player Career Span  Career Start  Career End  Matches Played  \
# 14  JE Root (2012-2018)   2012-2018          2012        2018              77
#
#    Innings Batted Not Outs Runs Scored Highest Innings Score  \
# 14            141       12        6508                   254
#
#    Highest Innings Score Num Batting Avg Hundreds Scored  \
# 14                       254       50.44              15
#
#    Scores Of Fifty Or More Ducks Scored  Country  Player Count  \
# 14                      41            5  England             1
#
#     10000+ Runs Scored  50+ Batting Avg
# 14                   0                1

# %%
EngAshes = ['JE Root (2012-2018)', 'BA Stokes (2013-2018)', 'MM Ali (2014-2018)', 'JM Anderson (2003-2018)', 'JM Bairstow (2012-2018)', 'SCJ Broad (2007-2018)', 'RJ Burns (2018-2018)', 'JC Buttler (2014-2018)', 'SM Curran (2018-2018)', 'MJ Leach (2018-2018)', 'CR Woakes (2013-2018)']
EnglandPeople = TestBatting[TestBatting['Country'] == 'England']
Eng2019 = EnglandPeople.loc[EnglandPeople['Player'].isin(EngAshes)]
Eng2019.head(2)
# Out:
#                      Player Career Span  Career Start  Career End  \
# 14      JE Root (2012-2018)   2012-2018          2012        2018
# 35  JM Bairstow (2012-2018)   2012-2018          2012        2018
#
#     Matches Played Innings Batted Not Outs Runs Scored Highest Innings Score  \
# 14              77            141       12        6508                   254
# 35              60            104        6        3696                  167*
#
#    Highest Innings Score Num Batting Avg Hundreds Scored  \
# 14                       254       50.44              15
# 35                       167       37.71               6
#
#    Scores Of Fifty Or More Ducks Scored  Country  Player Count  \
# 14                      41            5  England             1
# 35                      19            8  England             1
#
#     10000+ Runs Scored  50+ Batting Avg
# 14                   0                1
# 35                   0                0

# %%
AusAshes = ['TD Paine (2010-2019)', 'PJ Cummins (2011-2019)', 'TM Head (2018-2019)', 'CT Bancroft (2017-2018)', 'MS Harris (2018-2019)', 'JR Hazlewood (2014-2019)', 'UT Khawaja (2011-2019)', 'M Labuschagne (2018-2019)', 'NM Lyon (2011-2019)', 'MR Marsh (2014-2018)', 'JL Pattinson (2011-2016)', 'PM Siddle (2008-2018)', 'SPD Smith (2010-2018)', 'MA Starc (2011-2019)', 'MS Wade (2012-2017)', 'DA Warner (2011-2018)']
AusPeople = TestBatting[TestBatting['Country'] == 'Australia']
Aus2019 = AusPeople.loc[AusPeople['Player'].isin(AusAshes)]
Aus2019.head(2)
# Out:
#                     Player Career Span  Career Start  Career End  \
# 700  DA Warner (2011-2018)   2011-2018          2011        2018
# 702  SPD Smith (2010-2018)   2010-2018          2010        2018
#
#      Matches Played Innings Batted Not Outs Runs Scored Highest Innings Score  \
# 700              74            137        5        6363                   253
# 702              64            117       16        6199                   239
#
#     Highest Innings Score Num Batting Avg Hundreds Scored  \
# 700                       253       48.20              21
# 702                       239       61.37              23
#
#     Scores Of Fifty Or More Ducks Scored    Country  Player Count  \
# 700                      29            6  Australia             1
# 702                      24            4  Australia             1
#
#      10000+ Runs Scored  50+ Batting Avg
# 700                   0                0
# 702                   0                1

# %%
AusPeople["Innings Batted"].value_counts().plot(kind='bar')

# %%
#AshesPeople.sort_values(["Batting Avg"], ascending=[True], inplace=True)
#AshesPeople = pd.concat([Eng2019, Aus2019])

# %%
import seaborn as sns
sns.set()
Ashes2019 = ['TD Paine (2010-2019)', 'PJ Cummins (2011-2019)', 'TM Head (2018-2019)', 'CT Bancroft (2017-2018)', 'MS Harris (2018-2019)', 'JR Hazlewood (2014-2019)', 'UT Khawaja (2011-2019)', 'M Labuschagne (2018-2019)', 'NM Lyon (2011-2019)', 'MR Marsh (2014-2018)', 'JL Pattinson (2011-2016)', 'PM Siddle (2008-2018)', 'SPD Smith (2010-2018)', 'MA Starc (2011-2019)', 'MS Wade (2012-2017)', 'DA Warner (2011-2018)', 'JE Root (2012-2018)', 'BA Stokes (2013-2018)', 'MM Ali (2014-2018)', 'JM Anderson (2003-2018)', 'JM Bairstow (2012-2018)', 'SCJ Broad (2007-2018)', 'RJ Burns (2018-2018)', 'JC Buttler (2014-2018)', 'SM Curran (2018-2018)', 'MJ Leach (2018-2018)', 'CR Woakes (2013-2018)']
Ashes = TestBatting.loc[TestBatting['Player'].isin(Ashes2019)]

sns.scatterplot('Innings Batted', 'Batting Avg', size = "Matches Played", hue="Country", sizes=(40, 400), alpha=0.99, palette="muted", data = Ashes);

# %%
x,y = zip(*li)
plt.scatter(*zip(*li))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-75-aaf0e3d60410> in <module>
# ----> 1 x,y = zip(*li)
#       2 plt.scatter(*zip(*li))
#
# NameError: name 'li' is not defined

# %%
Ashes2019 = ['TD Paine (2010-2019)', 'PJ Cummins (2011-2019)', 'TM Head (2018-2019)', 'CT Bancroft (2017-2018)', 'MS Harris (2018-2019)', 'JR Hazlewood (2014-2019)', 'UT Khawaja (2011-2019)', 'M Labuschagne (2018-2019)', 'NM Lyon (2011-2019)', 'MR Marsh (2014-2018)', 'JL Pattinson (2011-2016)', 'PM Siddle (2008-2018)', 'SPD Smith (2010-2018)', 'MA Starc (2011-2019)', 'MS Wade (2012-2017)', 'DA Warner (2011-2018)', 'JE Root (2012-2018)', 'BA Stokes (2013-2018)', 'MM Ali (2014-2018)', 'JM Anderson (2003-2018)', 'JM Bairstow (2012-2018)', 'SCJ Broad (2007-2018)', 'RJ Burns (2018-2018)', 'JC Buttler (2014-2018)', 'SM Curran (2018-2018)', 'MJ Leach (2018-2018)', 'CR Woakes (2013-2018)']
Ashes = TestBatting.loc[TestBatting['Player'].isin(Ashes2019)]
sns.catplot(y='Batting Avg', x='Country', palette="muted", kind = "swarm", data = Ashes);

# %%
names='England', 'Australia'
size=[12,11]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 
my_circle=plt.Circle( (0,0), 0.7, color='white')

# %%
Ashes['Matches Played'].value_counts()[:20].plot(kind='barh')

# %%
sns.catplot(x='Batting Avg', y='Country', data = Ashes);

# %%
sns.catplot(x="Batting Avg", y="Innings Batted", palette="ch:.25", data=Ashes);

# %%
#Ashes['Innings Batted']

# %%
Ashes2019 = ['TD Paine (2010-2019)', 'PJ Cummins (2011-2019)', 'TM Head (2018-2019)', 'CT Bancroft (2017-2018)', 'MS Harris (2018-2019)', 'JR Hazlewood (2014-2019)', 'UT Khawaja (2011-2019)', 'M Labuschagne (2018-2019)', 'NM Lyon (2011-2019)', 'MR Marsh (2014-2018)', 'JL Pattinson (2011-2016)', 'PM Siddle (2008-2018)', 'SPD Smith (2010-2018)', 'MA Starc (2011-2019)', 'MS Wade (2012-2017)', 'DA Warner (2011-2018)', 'JE Root (2012-2018)', 'BA Stokes (2013-2018)', 'MM Ali (2014-2018)', 'JM Anderson (2003-2018)', 'JM Bairstow (2012-2018)', 'SCJ Broad (2007-2018)', 'RJ Burns (2018-2018)', 'JC Buttler (2014-2018)', 'SM Curran (2018-2018)', 'MJ Leach (2018-2018)', 'CR Woakes (2013-2018)']
Ashes = TestBatting.loc[TestBatting['Player'].isin(Ashes2019)]
Ashes.sort_values(by = ["Matches Played"], ascending = False).plot(kind='barh')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid")

# Initialize the matplotlib figure
f, ax = plt.subplots(figsize=(6, 15))

# Plot the total crashes
sns.set_color_codes("pastel")
sns.barplot(x="Runs Scored", y="Matches Played", data=Ashes, label="Hundreds Scored",  color = "b")

# Plot the crashes where alcohol was involved
sns.set_color_codes("muted")
sns.barplot(x="Hundreds Scored", y="Matches Played", data=Ashes, label="Runs Scored", color = "b")

ax.legend(ncol=2, loc="lower right", frameon=True)
ax.set(xlim=(0, 24), ylabel="",
       xlabel="Batting Average")
sns.despine(left=True, bottom=True)

# %%
g = sns.catplot(x="Hundreds Scored", y="Runs Scored", hue="Country", data=Ashes, kind="bar", palette="muted")
g.despine(left=True)
g.set_ylabels("Runs Scored")

# %%
ax = sns.boxenplot(x="Runs Scored", y="Hundreds Scored", hue="Country", data=Ashes, palette="Set3")

# %%
Ashes["Runs Scored"].apply(pd.to_numeric, errors='coerce')
Ashes["Hundreds Scored"].apply(pd.to_numeric, errors='coerce')
# Out:
# 14     15
# 35      6
# 42      1
# 43      6
# 45      5
# 73      1
# 94      0
# 102     1
# 204     0
# 329     0
# 469     0
# 700    21
# 702    23
# 733     7
# 768     0
# 775     2
# 785     0
# 797     0
# 799     0
# 809     2
# 837     0
# 865     0
# 872     0
# 876     0
# 887     0
# 899     0
# 959     0
# Name: Hundreds Scored, dtype: int64

# %%
totalAshes = Ashes.sum(axis = 0, skipna = True)
